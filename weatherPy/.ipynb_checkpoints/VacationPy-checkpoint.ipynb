# %% [markdown]
# # VacationPy
# ---
#
# ## Starter Code to Import Libraries and Load the Weather and Coordinates Data

# %%
# Dependencies and Setup
import hvplot.pandas
import pandas as pd
import requests
import warnings
warnings.filterwarnings('ignore')

# Import API key
from api_keys import geoapify_key

# %%
# Load the CSV file created in Part 1 into a Pandas DataFrame
city_data_df = pd.read_csv("output_data/cities.csv")

# Display sample data
city_data_df.head()
# Out:
#    City_ID             City      Lat       Lng  Max Temp  Humidity  \
# 0        0     norman wells  65.2820 -126.8329    -27.98        69
# 1        1        busselton -33.6500  115.3333     22.30        38
# 2        2            kapaa  22.0752 -159.3190     26.18        87
# 3        3  verkhnevilyuysk  63.4453  120.3167    -23.37        94
# 4        4          ushuaia -54.8000  -68.3000      5.79        65
#
#    Cloudiness  Wind Speed Country        Date
# 0          20        8.75      CA  1670294441
# 1           0        4.29      AU  1670294441
# 2          75        6.17      US  1670294442
# 3         100        3.17      RU  1670294442
# 4          40        7.72      AR  1670294443

# %% [markdown]
# ---
#
# ### Step 1: Create a map that displays a point for every city in the `city_data_df` DataFrame. The size of the point should be the humidity in each city.

# %%
# %%capture --no-display

# Configure the map plot
map_plot = city_data_df.hvplot.points("Lng","Lat",geo=True,tiles="OSM",s="Humidity",c="City",alpha=0.6)

# Display the map
map_plot
# Out:
# :Overlay
#    .Tiles.I  :Tiles   [x,y]
#    .Points.I :Points   [Lng,Lat]   (City,Humidity)

# %% [markdown]
# ### Step 2: Narrow down the `city_data_df` DataFrame to find your ideal weather condition

# %%
# Narrow down cities that fit criteria and drop any results with null values
vacation_list = city_data_df.loc[(city_data_df["Max Temp"] > 18) & (city_data_df["Max Temp"] < 26) & (city_data_df["Wind Speed"] < 4) & (city_data_df["Cloudiness"] < 4)]

# Drop any rows with null values
vacation_list = vacation_list.dropna(how='any')
del vacation_list["City_ID"]

# Display sample data
vacation_list
# Out:
#                        City      Lat       Lng  Max Temp  Humidity  \
# 18                cape town -33.9258   18.4232     19.10        72
# 65                  salalah  17.0151   54.0924     22.05        60
# 101                    tura  25.5198   90.2201     21.16        63
# 129                   unhel  23.3333   75.5667     18.69        56
# 152                ambilobe -13.2000   49.0500     24.01        82
# 167                 midland  31.9974 -102.0779     20.38        57
# 191               taoudenni  22.6783   -3.9836     24.21        23
# 211              rio grande -32.0350  -52.0986     19.50        90
# 250                acapulco  16.8634  -99.8901     25.24        79
# 255               abu dhabi  24.4667   54.3667     22.20        86
# 365                    bara  10.3744   10.7288     19.29        22
# 390                 amarpur  25.0333   86.9000     18.27        40
# 407                   houma  29.5958  -90.7195     20.56        96
# 435               tecoanapa  16.5167  -98.7500     25.29        77
# 441  san diego de los banos  22.6467  -83.3697     19.56        85
# 445             keti bandar  24.1447   67.4497     20.95        31
# 501                umm lajj  25.0213   37.2685     22.47        73
# 532          merritt island  28.5392  -80.6720     21.13        81
# 533                pochutla  15.7432  -96.4661     24.34        68
#
#      Cloudiness  Wind Speed Country        Date
# 18            0        3.60      ZA  1670294355
# 65            0        3.09      OM  1670294471
# 101           0        0.60      IN  1670294492
# 129           2        3.05      IN  1670294502
# 152           3        1.06      MG  1670294510
# 167           0        3.09      US  1670294253
# 191           2        1.74      ML  1670294528
# 211           0        3.79      BR  1670294541
# 250           0        2.16      MX  1670294536
# 255           0        2.06      AE  1670294562
# 365           3        3.05      NG  1670294602
# 390           0        3.09      IN  1670294611
# 407           0        2.06      US  1670294578
# 435           0        2.00      MX  1670294627
# 441           1        1.65      CU  1670294629
# 445           0        3.82      PK  1670294630
# 501           0        2.29      SA  1670294659
# 532           0        0.00      US  1670294677
# 533           0        1.39      MX  1670294677

# %% [markdown]
# ### Step 3: Create a new DataFrame called `hotel_df`.

# %%
# Use the Pandas copy function to create DataFrame called hotel_df to store the city, country, coordinates, and humidity
hotel_df = vacation_list[["City","Country","Lat","Lng","Humidity"]]

# Add an empty column, "Hotel Name," to the DataFrame so you can store the hotel found using the Geoapify API
hotel_df["Hotel Name"] = ""

# Display sample data
hotel_df
# Out:
#                        City Country      Lat       Lng  Humidity Hotel Name
# 18                cape town      ZA -33.9258   18.4232        72
# 65                  salalah      OM  17.0151   54.0924        60
# 101                    tura      IN  25.5198   90.2201        63
# 129                   unhel      IN  23.3333   75.5667        56
# 152                ambilobe      MG -13.2000   49.0500        82
# 167                 midland      US  31.9974 -102.0779        57
# 191               taoudenni      ML  22.6783   -3.9836        23
# 211              rio grande      BR -32.0350  -52.0986        90
# 250                acapulco      MX  16.8634  -99.8901        79
# 255               abu dhabi      AE  24.4667   54.3667        86
# 365                    bara      NG  10.3744   10.7288        22
# 390                 amarpur      IN  25.0333   86.9000        40
# 407                   houma      US  29.5958  -90.7195        96
# 435               tecoanapa      MX  16.5167  -98.7500        77
# 441  san diego de los banos      CU  22.6467  -83.3697        85
# 445             keti bandar      PK  24.1447   67.4497        31
# 501                umm lajj      SA  25.0213   37.2685        73
# 532          merritt island      US  28.5392  -80.6720        81
# 533                pochutla      MX  15.7432  -96.4661        68

# %% [markdown]
# ### Step 4: For each city, use the Geoapify API to find the first hotel located within 10,000 metres of your coordinates.

# %%
# Set parameters to search for a hotel
radius = 10000
params = {
    "categories" : "accommodation.hotel",
    "apiKey" : geoapify_key,
    "limit" : 1
}

# Print a message to follow up the hotel search
print("Starting hotel search...")

# Iterate through the hotel_df DataFrame
for index, row in hotel_df.iterrows():
    # get latitude, longitude from the DataFrame
    latitude = row["Lat"]
    longitude = row["Lng"]
    
    # Add filter and bias parameters with the current city's latitude and longitude to the params dictionary
    params["filter"] = f"circle:{longitude},{latitude},{radius}"
    params["bias"] = f"proximity:{longitude},{latitude}"
    
    # Set base URL
    base_url = "https://api.geoapify.com/v2/places"


    # Make and API request using the params dictionaty
    name_address = requests.get(base_url, params=params)
    
    # Convert the API response to JSON format
    name_address = name_address.json()
    
    # Grab the first hotel from the results and store the name in the hotel_df DataFrame
    try:
        hotel_df.loc[index, "Hotel Name"] = name_address["features"][0]["properties"]["name"]
    except (KeyError, IndexError):
        # If no hotel is found, set the hotel name as "No hotel found".
        hotel_df.loc[index, "Hotel Name"] = "No hotel found"
        
    # Log the search results
    print(f"{hotel_df.loc[index, 'City']} - nearest hotel: {hotel_df.loc[index, 'Hotel Name']}")

# Display sample data
hotel_df
# Out:
# Starting hotel search...
# cape town - nearest hotel: Townhouse Hotel
# salalah - nearest hotel: Muscat International Hotel
# tura - nearest hotel: No hotel found
# unhel - nearest hotel: No hotel found
# ambilobe - nearest hotel: Hôtel National
# midland - nearest hotel: DoubleTree by Hilton Hotel Midland Plaza
# taoudenni - nearest hotel: No hotel found
# rio grande - nearest hotel: Hotel Vila Moura Executivo
# acapulco - nearest hotel: Hotel del Valle
# abu dhabi - nearest hotel: Marriott Downtown Abu-Dhabi
# bara - nearest hotel: No hotel found
# amarpur - nearest hotel: No hotel found
# houma - nearest hotel: Courtyard by Marriott Houma
# tecoanapa - nearest hotel: No hotel found
# san diego de los banos - nearest hotel: Hotel Mirador
# keti bandar - nearest hotel: No hotel found
# umm lajj - nearest hotel: No hotel found
# merritt island - nearest hotel: No hotel found
# pochutla - nearest hotel: Hotel El Patio
#                        City Country      Lat       Lng  Humidity  \
# 18                cape town      ZA -33.9258   18.4232        72
# 65                  salalah      OM  17.0151   54.0924        60
# 101                    tura      IN  25.5198   90.2201        63
# 129                   unhel      IN  23.3333   75.5667        56
# 152                ambilobe      MG -13.2000   49.0500        82
# 167                 midland      US  31.9974 -102.0779        57
# 191               taoudenni      ML  22.6783   -3.9836        23
# 211              rio grande      BR -32.0350  -52.0986        90
# 250                acapulco      MX  16.8634  -99.8901        79
# 255               abu dhabi      AE  24.4667   54.3667        86
# 365                    bara      NG  10.3744   10.7288        22
# 390                 amarpur      IN  25.0333   86.9000        40
# 407                   houma      US  29.5958  -90.7195        96
# 435               tecoanapa      MX  16.5167  -98.7500        77
# 441  san diego de los banos      CU  22.6467  -83.3697        85
# 445             keti bandar      PK  24.1447   67.4497        31
# 501                umm lajj      SA  25.0213   37.2685        73
# 532          merritt island      US  28.5392  -80.6720        81
# 533                pochutla      MX  15.7432  -96.4661        68
#
#                                    Hotel Name
# 18                            Townhouse Hotel
# 65                 Muscat International Hotel
# 101                            No hotel found
# 129                            No hotel found
# 152                            Hôtel National
# 167  DoubleTree by Hilton Hotel Midland Plaza
# 191                            No hotel found
# 211                Hotel Vila Moura Executivo
# 250                           Hotel del Valle
# 255               Marriott Downtown Abu-Dhabi
# 365                            No hotel found
# 390                            No hotel found
# 407               Courtyard by Marriott Houma
# 435                            No hotel found
# 441                             Hotel Mirador
# 445                            No hotel found
# 501                            No hotel found
# 532                            No hotel found
# 533                            Hotel El Patio

# %% [markdown]
# ### Step 5: Add the hotel name and the country as additional information in the hover message for each city in the map.

# %%
# %%capture --no-display

# Configure the map plot
map_hotel_plot = hotel_df.hvplot.points("Lng","Lat",geo=True,tiles="OSM",s="Humidity",c="City",alpha=0.6,hover_cols=["Hotel Name","Country"])

# Display the map
map_hotel_plot
# Out:
# :Overlay
#    .Tiles.I  :Tiles   [x,y]
#    .Points.I :Points   [Lng,Lat]   (City,Humidity,Hotel Name,Country)
